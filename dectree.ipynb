# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

data = {
    "study_hours": [2,3,4,6,7,8],
    "attendance": [60,65,70,75,80,85],
    "passed": [0,0,0,1,1,1]
}

df = pd.DataFrame(data)

x = df[['study_hours', 'attendance']]
y = df['passed']  

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

model = DecisionTreeClassifier()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))


new_student = [[7, 80]]
y_pred_new = model.predict(new_student)
print("Prediction:", y_pred_new[0])
print("passed (0 = No, 1 = Yes):", y_pred_new[0])

plt.plot(df['study_hours'], df['passed'], marker='v')
plt.xlabel("study_hours")
plt.ylabel("passed (0 = No, 1 = Yes)")
plt.title("Decision Tree Classification Data")
plt.grid(True)   
plt.show()
# Out:
# Accuracy: 1.0
# Prediction: 1
# passed (0 = No, 1 = Yes): 1
# c:\Users\kerala\OneDrive\Desktop\ml\sck\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
#Question 1: Loan Approval Prediction
#Dataset:

#Income (₹ in thousands), Credit_Score (300–900), Approved (0/1)

#30, 550, 0
#40, 600, 0
#50, 650, 1
#60, 700, 1
#70, 750, 1
#35, 580, 0

#Tasks:

#1.Train a DecisionTreeClassifier to predict loan approval.

#2. Show the accuracy_score and confusion_matrix.

#3. Predict whether a person with
#Income = 55k, Credit Score = 680
#will get the loan approved.
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

data = {
    "income": [30, 40, 50, 60, 70, 35],
    "credit_score": [550, 600, 650, 700, 750, 580],
    "approved": [0, 0, 1, 1, 1, 0]
}

df = pd.DataFrame(data)

X = df[['income','credit_score']]
y = df['approved']

X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.3, random_state = 42)
model = DecisionTreeClassifier()
model.fit(X_train, Y_train)

y_pred = model.predict(X_test)

print("Accuracy Score:", accuracy_score(Y_test, y_pred))

new_person = [[55, 680]]
prediction = model.predict(new_person)

print("Approved (1 = Yes, 0 = No)", prediction[0])

plt.plot(df['income'], df['approved'], marker='o')
plt.xlabel("Income (in thousands)")
plt.ylabel("Approved (0 = No, 1 = Yes)")
plt.title("Loan Approval Classification Data")
plt.grid(True)
plt.show()
# Out:
# Accuracy Score: 1.0
# Approved (1 = Yes, 0 = No) 1
# c:\Users\kerala\OneDrive\Desktop\ml\sck\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
